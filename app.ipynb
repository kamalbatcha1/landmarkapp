# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for Landmark Classification
#
# ### A simple app
#
# In this notebook we build a very simple app that uses our exported model.
#
# > <img src="static_images/icons/noun-info-2558213.png" alt="?" style="width:25px"/> Note how we are not importing anything from our source code (we do not use any module from the ``src`` directory). This is because the exported model, differently from the model weights, is a standalone serialization of our model and therefore it does not need anything else. You can ship that file to anybody, and as long as they can import ``torch``, they will be able to use your model. This is very important for releasing pytorch models to production.
#
# ### Test your app
# Go to a search engine for images (like Google Images) and search for images of some of the landmarks, like the Eiffel Tower, the Golden Gate Bridge, Machu Picchu and so on. Save a few examples locally, then upload them to your app to see how your model behaves!
#
# The app will show the top 5 classes that the model think are most relevant for the picture you have uploaded

# %%
from ipywidgets import VBox, Button, FileUpload, Output, Label
from PIL import Image
from IPython.display import display
import io
import numpy as np
import torchvision
import torchvision.transforms as T
import torch

# Decide which model you want to use among the ones exported
learn_inf = torch.jit.load("transfer_exported.pt")

def on_click_classify(change):

    # Load image that has been uploaded
    fn = io.BytesIO(btn_upload.data[-1])

    img = Image.open(fn)
    img.load()

    # Let's clear the previous output (if any)
    out_pl.clear_output()

    # Display the image
    with out_pl:

        ratio = img.size[0] / img.size[1]
        c = img.copy()
        c.thumbnail([ratio * 200, 200])
        display(c)

    # Transform to tensor
    timg = T.ToTensor()(img).unsqueeze_(0)

    # Calling the model
    softmax = learn_inf(timg).data.cpu().numpy().squeeze()
    
    # Get the indexes of the classes ordered by softmax
    # (larger first)
    idxs = np.argsort(softmax)[::-1]
    
    # Loop over the classes with the largest softmax
    for i in range(5):
        # Get softmax value
        p = softmax[idxs[i]]
    
        # Get class name
        landmark_name = learn_inf.class_names[idxs[i]]
        
        labels[i].value = f"{landmark_name} (prob: {p:.2f})"


# Putting back btn_upload to a widget for next cell
btn_upload = FileUpload()

btn_run = Button(description="Classify")
btn_run.on_click(on_click_classify)

labels = []
for _ in range(5):
    labels.append(Label())

out_pl = Output()
out_pl.clear_output()

wgs = [Label("Please upload a picture of a landmark"), btn_upload, btn_run, out_pl]
wgs.extend(labels)

VBox(wgs)

# %% [markdown]
# ## (optional) Standalone app or web app
#
# You can run this notebook as a standalone app on your computer by following these steps:
#
# 1. Download this notebook in a directory on your machine
# 2. Download the model export (for example, ``checkpoints/transfer_exported.pt``) in a subdirectory called ``checkpoints`` within the directory where you save the app.ipynb notebook
# 3. Install voila if you don't have it already (``pip install voila``)
# 4. Run your app: ``voila app.ipynb --show_tracebacks=True``
# 5. Customize your notebook to make your app prettier and rerun voila
#
# You can also deploy this app as a website using Binder: https://voila.readthedocs.io/en/stable/deploy.html#deployment-on-binder

# %% [markdown]
# # Create your submission archive
#
# Now that you are done with your project, please run the following cell. It will generate a file containing all the code you have written, as well as the notebooks. Please submit that file to complete your project

# %%
# !python src/create_submit_pkg.py

# %%
import os
os.environ['VOILA_SHOW_TRACEBACK'] = 'True'
# !voila app.ipynb

# %%
# !pip install --upgrade voila
# !pip install --upgrade jupyter-server
# Out:
# Requirement already satisfied: voila in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (0.4.1)
# Requirement already satisfied: jupyter-client<=7.4.1,>=6.1.3 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from voila) (7.4.1)
# Requirement already satisfied: jupyter-core>=4.11.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from voila) (4.11.1)
# Requirement already satisfied: jupyter-server<2.0.0,>=1.18 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from voila) (1.23.4)
# Requirement already satisfied: jupyterlab-server<3,>=2.3.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from voila) (2.16.5)
# Requirement already satisfied: nbclient<0.8,>=0.4.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from voila) (0.5.13)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from voila) (6.5.4)
# Requirement already satisfied: traitlets<6,>=5.0.3 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from voila) (5.7.1)
# Requirement already satisfied: websockets>=9.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from voila) (11.0.3)
# Requirement already satisfied: entrypoints in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (1.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (23.2.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (6.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-core>=4.11.0->voila) (305.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (3.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (3.1.2)
# Requirement already satisfied: nbformat>=5.2.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (5.7.0)
# Requirement already satisfied: packaging in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (22.0)
# Requirement already satisfied: prometheus-client in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.14.1)
# Requirement already satisfied: Send2Trash in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.58.0)
# Requirement already satisfied: pywinpty in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (2.0.2)
# Requirement already satisfied: babel>=2.10 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.11.0)
# Requirement already satisfied: importlib-metadata>=4.8.3 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.11.3)
# Requirement already satisfied: json5>=0.9.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.9.6)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.17.3)
# Requirement already satisfied: requests>=2.28 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.28.1)
# Requirement already satisfied: lxml in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (4.11.1)
# Requirement already satisfied: bleach in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (2.11.2)
# Requirement already satisfied: tinycss2 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (1.2.1)
# Requirement already satisfied: idna>=2.8 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=1.18->voila) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=1.18->voila) (1.2.0)
# Requirement already satisfied: typing-extensions in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=1.18->voila) (4.4.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.3.0->voila) (2022.7)
# Requirement already satisfied: zipp>=0.5 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from importlib-metadata>=4.8.3->jupyterlab-server<3,>=2.3.0->voila) (3.11.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (22.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (5.2.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (0.18.0)
# Requirement already satisfied: fastjsonschema in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbformat>=5.2.0->jupyter-server<2.0.0,>=1.18->voila) (2.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client<=7.4.1,>=6.1.3->voila) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (2022.12.7)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from bleach->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (2.21)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages)
# DEPRECATION: pytorch-lightning 1.7.7 has a non-standard dependency specifier torch>=1.9.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: jupyter-server in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (1.23.4)
# Collecting jupyter-server
#   Using cached jupyter_server-1.24.0-py3-none-any.whl (347 kB)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server) (3.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server) (3.1.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server) (7.4.1)
# Collecting jupyter-core!=5.0.*,>=4.12 (from jupyter-server)
#   Using cached jupyter_core-4.12.0-py3-none-any.whl (89 kB)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server) (6.5.4)
# Requirement already satisfied: nbformat>=5.2.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server) (5.7.0)
# Requirement already satisfied: packaging in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server) (22.0)
# Requirement already satisfied: prometheus-client in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server) (0.14.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server) (23.2.0)
# Requirement already satisfied: Send2Trash in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server) (0.17.1)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server) (6.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server) (5.7.1)
# Requirement already satisfied: websocket-client in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server) (0.58.0)
# Requirement already satisfied: pywinpty in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-server) (2.0.2)
# Requirement already satisfied: idna>=2.8 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server) (1.2.0)
# Requirement already satisfied: typing-extensions in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server) (4.4.0)
# Requirement already satisfied: entrypoints in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server) (1.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server) (305.1)
# Requirement already satisfied: lxml in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert>=6.4.4->jupyter-server) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert>=6.4.4->jupyter-server) (4.11.1)
# Requirement already satisfied: bleach in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert>=6.4.4->jupyter-server) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert>=6.4.4->jupyter-server) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert>=6.4.4->jupyter-server) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert>=6.4.4->jupyter-server) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert>=6.4.4->jupyter-server) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert>=6.4.4->jupyter-server) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert>=6.4.4->jupyter-server) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert>=6.4.4->jupyter-server) (2.11.2)
# Requirement already satisfied: tinycss2 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbconvert>=6.4.4->jupyter-server) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbformat>=5.2.0->jupyter-server) (2.16.2)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbformat>=5.2.0->jupyter-server) (4.11.3)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from nbformat>=5.2.0->jupyter-server) (4.17.3)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from argon2-cffi->jupyter-server) (21.2.0)
# Requirement already satisfied: six in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from websocket-client->jupyter-server) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from importlib-metadata>=3.6->nbformat>=5.2.0->jupyter-server) (3.11.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server) (22.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server) (5.2.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server) (0.18.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server) (2.21)
# Installing collected packages: jupyter-core, jupyter-server
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter_core 4.11.1
#     Uninstalling jupyter_core-4.11.1:
#       Successfully uninstalled jupyter_core-4.11.1
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.23.4
#     Uninstalling jupyter-server-1.23.4:
#       Successfully uninstalled jupyter-server-1.23.4
# Successfully installed jupyter-core-4.12.0 jupyter-server-1.24.0
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda\envs\cuda_pytorch\lib\site-packages)
# DEPRECATION: pytorch-lightning 1.7.7 has a non-standard dependency specifier torch>=1.9.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
